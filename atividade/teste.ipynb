# %%
import pandas as pd
copa_brasil = pd.read_csv("mundo_transfermarkt_competicoes_copa_brasil.csv")
copa_brasil
# Out:
#      ano_campeonato        data   horario             fase       tipo_fase  \
# 0              2020  2021-03-07  17:00:00           Final    Jogo De Volta
# 1              2020  2021-02-28  15:00:00           Final      Jogo De Ida
# 2              2020  2020-12-30  20:30:00     Semi-Finais   Jogos De Volta
# 3              2020  2020-12-30  20:30:00     Semi-Finais   Jogos De Volta
# 4              2020  2020-12-23  20:30:00     Semi-Finais     Jogos De Ida
# ..              ...         ...       ...              ...             ...
# 593            2021  2021-03-25  14:30:00  1ª Eliminatória      Jogo Único
# 594            2021  2021-03-25  14:30:00  1ª Eliminatória      Jogo Único
# 595            2021  2021-03-26  14:30:00  1ª Eliminatória      Jogo Único
# 596            2021  2021-03-26  14:30:00  1ª Eliminatória      Jogo Único
# 597            2021  2021-03-27  14:30:00  1ª Eliminatória      Jogo Único
#
#                                        estadio  \
# ...
